# %%
import numpy as np
import pandas as pd
import pandas as pd
from sklearn import linear_model
import statsmodels.api as sm

# %%
df = pd.read_csv("final_sample_june3_2020.csv")
df
# Out:
#       ID  EntorhinalCortexL_CT  EntorhinalCortexR_CT  GROUP  GROUP_1  AGE  \
# 0   1005                3.9279                4.1086      1        1   30
# 1   1017                4.2634                4.2980      1        1   39
# 2   1018                4.0669                4.2041      1        1   27
# 3   1019                3.7527                3.7051      1        1   25
# 4   1021                3.9626                4.1177      1        1   23
# 5   1023                4.0428                4.1605      1        1   25
# 6   1025                3.5169                3.3441      1        1   21
# 7   1027                4.0582                4.2483      1        1   39
# 8   1036                3.5768                3.8036      1        1   27
# 9   1038                4.1192                4.2275      1        1   32
# 10  1043                4.0422                4.0858      1        1   24
# 11  1048                3.9466                3.9815      1        1   38
# ...

# %%
df.RG_CVLT = df['RG_CVLT'].astype(int)
df.LFR_CVLT = df['LFR_CVLT'].astype(int)
df.Estradiol = df['Estradiol'].astype(int)
df.EntorhinalCortexL_CTz = df['EntorhinalCortexL_CTz'].astype(int)
df.EntorhinalCortexR_CTz = df['EntorhinalCortexR_CTz'].astype(int)
df.Agez = df['Agez'].astype(int)
df.GROUP_1 = df['GROUP_1'].astype(str)

# %%
import pandas as pd
from sklearn import linear_model
import statsmodels.api as sm

# %%
X = df[["Agez", "EntorhinalCortexL_CTz", "Estradiol"]]
y = df["LFR_CVLT"]

# %%
model = sm.OLS(y, X).fit()
predictions = model.predict(X)
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:               LFR_CVLT   R-squared (uncentered):                   0.122
# Model:                            OLS   Adj. R-squared (uncentered):              0.069
# Method:                 Least Squares   F-statistic:                              2.311
# Date:                Wed, 03 Jun 2020   Prob (F-statistic):                      0.0875
# Time:                        10:59:22   Log-Likelihood:                         -207.56
# No. Observations:                  53   AIC:                                      421.1
# Df Residuals:                      50   BIC:                                      427.0
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                             coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %%
regr = linear_model.LinearRegression()
regr.fit(X, y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
model = sm.OLS(y, X).fit()
predictions = model.predict(X) 

print_model = model.summary()
print(print_model)
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:               LFR_CVLT   R-squared (uncentered):                   0.122
# Model:                            OLS   Adj. R-squared (uncentered):              0.069
# Method:                 Least Squares   F-statistic:                              2.311
# Date:                Wed, 03 Jun 2020   Prob (F-statistic):                      0.0875
# Time:                        10:59:42   Log-Likelihood:                         -207.56
# No. Observations:                  53   AIC:                                      421.1
# Df Residuals:                      50   BIC:                                      427.0
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# ...

# %%
X = df[["Agez", "EntorhinalCortexL_CTz", "Estradiol"]]
y = df["RG_CVLT"]

# %%
regr = linear_model.LinearRegression()
regr.fit(X, y)

model = sm.OLS(y, X).fit()
predictions = model.predict(X) 

print_model = model.summary()
print(print_model)
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                RG_CVLT   R-squared (uncentered):                   0.136
# Model:                            OLS   Adj. R-squared (uncentered):              0.084
# Method:                 Least Squares   F-statistic:                              2.630
# Date:                Wed, 03 Jun 2020   Prob (F-statistic):                      0.0603
# Time:                        11:00:30   Log-Likelihood:                         -216.48
# No. Observations:                  53   AIC:                                      439.0
# Df Residuals:                      50   BIC:                                      444.9
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# ...

# %%
X = df[["Agez", "EntorhinalCortexR_CTz", "Estradiol"]]
y = df["RG_CVLT"]

regr = linear_model.LinearRegression()
regr.fit(X, y)

model = sm.OLS(y, X).fit()
predictions = model.predict(X) 

print_model = model.summary()
print(print_model)
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                RG_CVLT   R-squared (uncentered):                   0.169
# Model:                            OLS   Adj. R-squared (uncentered):              0.119
# Method:                 Least Squares   F-statistic:                              3.389
# Date:                Wed, 03 Jun 2020   Prob (F-statistic):                      0.0250
# Time:                        11:00:56   Log-Likelihood:                         -215.46
# No. Observations:                  53   AIC:                                      436.9
# Df Residuals:                      50   BIC:                                      442.8
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# ...

# %%
X = df[["Agez", "EntorhinalCortexL_CTz", "Estradiol"]]
y = df["RG_CVLT"]

regr = linear_model.LinearRegression()
regr.fit(X, y)

model = sm.OLS(y, X).fit()
predictions = model.predict(X) 

print_model = model.summary()
print(print_model)
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                RG_CVLT   R-squared (uncentered):                   0.136
# Model:                            OLS   Adj. R-squared (uncentered):              0.084
# Method:                 Least Squares   F-statistic:                              2.630
# Date:                Wed, 03 Jun 2020   Prob (F-statistic):                      0.0603
# Time:                        11:01:12   Log-Likelihood:                         -216.48
# No. Observations:                  53   AIC:                                      439.0
# Df Residuals:                      50   BIC:                                      444.9
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# ...
